# %%
#import dependencies
import os
import csv
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt
import requests
from scipy import stats
from scipy.stats import linregress

# %%
happy2015_df = pd.read_csv('/Resources/2015.csv')
happy2016_df = pd.read_csv('2016.csv')
happy2017_df = pd.read_csv('2017.csv')
happy2018_df = pd.read_csv('2018.csv')
happy2019_df = pd.read_csv('2019.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-8b773644dae3> in <module>
# ----> 1 happy2015_df = pd.read_csv('2015.csv')
#       2 happy2016_df = pd.read_csv('2016.csv')
#       3 happy2017_df = pd.read_csv('2017.csv')
#       4 happy2018_df = pd.read_csv('2018.csv')
#       5 happy2019_df = pd.read_csv('2019.csv')
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File 2015.csv does not exist: '2015.csv'

# %%
#the survey changed over the years, so we need to clean the data up.
norm2015_df = happy2015_df.drop(['Region', 'Standard Error', 'Dystopia Residual'], axis=1)
norm2015_df = norm2015_df[['Country', 'Happiness Rank', 'Happiness Score', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity']]
norm2015_df.columns = ["Country or Region", "Happiness Rank", "Happiness Score", "GDP per Capita", "Social Support", "Healthy Life Expectancy", "Freedom", "Trust", "Generosity"]

norm2016_df = happy2016_df.drop(['Region','Lower Confidence Interval', 'Upper Confidence Interval', 'Dystopia Residual'], axis=1)
norm2016_df = norm2016_df[['Country', 'Happiness Rank', 'Happiness Score', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity']]
norm2016_df.columns = ["Country or Region", "Happiness Rank", "Happiness Score", "GDP per Capita", "Social Support", "Healthy Life Expectancy", "Freedom", "Trust", "Generosity"]

norm2017_df = happy2017_df.drop(['Whisker.high', 'Whisker.low', 'Dystopia.Residual'], axis=1)
norm2017_df = norm2017_df[['Country', 'Happiness.Rank', 'Happiness.Score', 'Economy..GDP.per.Capita.', 'Family', 'Health..Life.Expectancy.', 'Freedom', 'Trust..Government.Corruption.', 'Generosity']]
norm2017_df.columns = ["Country or Region", "Happiness Rank", "Happiness Score", "GDP per Capita", "Social Support", "Healthy Life Expectancy", "Freedom", "Trust", "Generosity"]

#norm2015_df = norm2015_df[['Country', 'Happiness Rank', 'Happiness Score', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity']]

#happy2018_df.head()
norm2018_df = happy2018_df[['Country or region', 'Overall rank', 'Score', 'GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Perceptions of corruption', 'Generosity']]
norm2018_df.columns = ["Country or Region", "Happiness Rank", "Happiness Score", "GDP per Capita", "Social Support", "Healthy Life Expectancy", "Freedom", "Trust", "Generosity"]
#norm2018_df
norm2019_df = happy2019_df[['Country or region', 'Overall rank', 'Score', 'GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Perceptions of corruption', 'Generosity']]
norm2019_df.columns = ["Country or Region", "Happiness Rank", "Happiness Score", "GDP per Capita", "Social Support", "Healthy Life Expectancy", "Freedom", "Trust", "Generosity"]
norm2019_df
# Out:
#             Country or Region  Happiness Rank  Happiness Score  \
# 0                     Finland               1            7.769
# 1                     Denmark               2            7.600
# 2                      Norway               3            7.554
# 3                     Iceland               4            7.494
# 4                 Netherlands               5            7.488
# ..                        ...             ...              ...
# 151                    Rwanda             152            3.334
# 152                  Tanzania             153            3.231
# 153               Afghanistan             154            3.203
# 154  Central African Republic             155            3.083
# 155               South Sudan             156            2.853
#
#      GDP per Capita  Social Support  Healthy Life Expectancy  Freedom  Trust  \
# 0             1.340           1.587                    0.986    0.596  0.393
# 1             1.383           1.573                    0.996    0.592  0.410
# 2             1.488           1.582                    1.028    0.603  0.341
# 3             1.380           1.624                    1.026    0.591  0.118
# 4             1.396           1.522                    0.999    0.557  0.298
# ..              ...             ...                      ...      ...    ...
# 151           0.359           0.711                    0.614    0.555  0.411
# 152           0.476           0.885                    0.499    0.417  0.147
# 153           0.350           0.517                    0.361    0.000  0.025
# 154           0.026           0.000                    0.105    0.225  0.035
# 155           0.306           0.575                    0.295    0.010  0.091
#
#      Generosity
# 0         0.153
# 1         0.252
# 2         0.271
# 3         0.354
# 4         0.322
# ..          ...
# 151       0.217
# 152       0.276
# 153       0.158
# 154       0.235
# 155       0.202
#
# [156 rows x 9 columns]

# %%
# Merge the first two datasets on "Country" so that no data is lost 
combined_df_2015_2016 = pd.merge(norm2015_df, norm2016_df, how='outer', on='Country or Region')
# Rename our _x columns to "2015"
combined_df_2015_2016 = combined_df_2015_2016.rename(columns={"Happiness Rank_x":"Happiness Rank 2015", 
                                                              "Happiness Score_x":"Happiness Score 2015", 
                                                              "GDP per Capita_x":"GDP 2015",
                                                              "Social Support_x": "Social Support 2015",
                                                              "Healthy Life Expectancy_x": "Life Expectancy 2015",
                                                              "Freedom_x": "Freedom 2015",
                                                              "Trust_x": "Trust 2015",
                                                              "Generosity_x": "Generosity 2015"
                                                             })

# Rename our _y columns to "2016"
combined_df_2015_2016 = combined_df_2015_2016.rename(columns={"Happiness Rank_y":"Happiness Rank 2016", 
                                                              "Happiness Score_y":"Happiness Score 2016", 
                                                              "GDP per Capita_y":"GDP 2016",
                                                              "Social Support_y": "Social Support 2016",
                                                              "Healthy Life Expectancy_y": "Life Expectancy 2016",
                                                              "Freedom_y": "Freedom 2016",
                                                              "Trust_y": "Trust 2016",
                                                              "Generosity_y": "Generosity 2016"
                                                             })

# %%
combined_df_2015_2016_2017 = pd.merge(combined_df_2015_2016, norm2017_df, how='outer', on='Country or Region')
combined_df_2015_2016_2017 = combined_df_2015_2016_2017.rename(columns={"Happiness Rank":"Happiness Rank 2017", 
                                                              "Happiness Score":"Happiness Score 2017", 
                                                              "GDP per Capita":"GDP 2017",
                                                              "Social Support": "Social Support 2017",
                                                              "Healthy Life Expectancy": "Life Expectancy 2017",
                                                              "Freedom": "Freedom 2017",
                                                              "Trust": "Trust 2017",
                                                              "Generosity": "Generosity 2017"
                                                             })

# %%
combined_df_2015_2016_2017_2018 = pd.merge(combined_df_2015_2016_2017, norm2018_df, how='outer', on='Country or Region')
combined_df_2015_2016_2017_2018 = combined_df_2015_2016_2017_2018.rename(columns={"Happiness Rank":"Happiness Rank 2018", 
                                                              "Happiness Score":"Happiness Score 2018", 
                                                              "GDP per Capita":"GDP 2018",
                                                              "Social Support": "Social Support 2018",
                                                              "Healthy Life Expectancy": "Life Expectancy 2018",
                                                              "Freedom": "Freedom 2018",
                                                              "Trust": "Trust 2018",
                                                              "Generosity": "Generosity 2018"
                                                             })

# %%
combined_df_all= pd.merge(combined_df_2015_2016_2017_2018, norm2019_df, how='outer', on='Country or Region')
combined_df_all = combined_df_all.rename(columns={"Happiness Rank":"Happiness Rank 2019", 
                                                              "Happiness Score":"Happiness Score 2019", 
                                                              "GDP per Capita":"GDP 2019",
                                                              "Social Support": "Social Support 2019",
                                                              "Healthy Life Expectancy": "Life Expectancy 2019",
                                                              "Freedom": "Freedom 2019",
                                                              "Trust": "Trust 2019",
                                                              "Generosity": "Generosity 2019"
                                                             })

combined_df_all = combined_df_all.fillna(0)

# %%
combined_df_all = combined_df_all.set_index("Country or Region")
combined_df_all.head()
# Out:
#                    Happiness Rank 2015  Happiness Score 2015  GDP 2015  \
# Country or Region
# Switzerland                        1.0                 7.587   1.39651
# Iceland                            2.0                 7.561   1.30232
# Denmark                            3.0                 7.527   1.32548
# Norway                             4.0                 7.522   1.45900
# Canada                             5.0                 7.427   1.32629
#
#                    Social Support 2015  Life Expectancy 2015  Freedom 2015  \
# Country or Region
# Switzerland                    1.34951               0.94143       0.66557
# Iceland                        1.40223               0.94784       0.62877
# Denmark                        1.36058               0.87464       0.64938
# Norway                         1.33095               0.88521       0.66973
# Canada                         1.32261               0.90563       0.63297
#
#                    Trust 2015  Generosity 2015  Happiness Rank 2016  \
# Country or Region
# Switzerland           0.41978          0.29678                  2.0
# Iceland               0.14145          0.43630                  3.0
# Denmark               0.48357          0.34139                  1.0
# Norway                0.36503          0.34699                  4.0
# Canada                0.32957          0.45811                  6.0
#
#                    Happiness Score 2016  ...  Trust 2018  Generosity 2018  \
# Country or Region                        ...
# Switzerland                       7.509  ...       0.357            0.256
# Iceland                           7.501  ...       0.138            0.353
# Denmark                           7.526  ...       0.408            0.284
# Norway                            7.498  ...       0.340            0.286
# Canada                            7.404  ...       0.291            0.321
#
#                    Happiness Rank 2019  Happiness Score 2019  GDP 2019  \
# Country or Region
# Switzerland                        6.0                 7.480     1.452
# Iceland                            4.0                 7.494     1.380
# Denmark                            2.0                 7.600     1.383
# Norway                             3.0                 7.554     1.488
# Canada                             9.0                 7.278     1.365
#
#                    Social Support 2019  Life Expectancy 2019  Freedom 2019  \
# Country or Region
# Switzerland                      1.526                 1.052         0.572
# Iceland                          1.624                 1.026         0.591
# Denmark                          1.573                 0.996         0.592
# Norway                           1.582                 1.028         0.603
# Canada                           1.505                 1.039         0.584
#
#                    Trust 2019  Generosity 2019
# Country or Region
# Switzerland             0.343            0.263
# Iceland                 0.118            0.354
# Denmark                 0.410            0.252
# Norway                  0.341            0.271
# Canada                  0.308            0.285
#
# [5 rows x 40 columns]

# %%
new_df = combined_df_all[["Happiness Score 2015", "Happiness Score 2016", "Happiness Score 2017", "Happiness Score 2018", "Happiness Score 2019"]]
new_df
# Out:
#                          Happiness Score 2015  Happiness Score 2016  \
# Country or Region
# Switzerland                             7.587                 7.509
# Iceland                                 7.561                 7.501
# Denmark                                 7.527                 7.526
# Norway                                  7.522                 7.498
# Canada                                  7.427                 7.404
# ...                                       ...                   ...
# Hong Kong S.A.R., China                 0.000                 0.000
# Trinidad & Tobago                       0.000                 0.000
# Northern Cyprus                         0.000                 0.000
# North Macedonia                         0.000                 0.000
# Gambia                                  0.000                 0.000
#
#                          Happiness Score 2017  Happiness Score 2018  \
# Country or Region
# Switzerland                             7.494                 7.487
# Iceland                                 7.504                 7.495
# Denmark                                 7.522                 7.555
# Norway                                  7.537                 7.594
# Canada                                  7.316                 7.328
# ...                                       ...                   ...
# Hong Kong S.A.R., China                 5.472                 0.000
# Trinidad & Tobago                       0.000                 6.192
# Northern Cyprus                         0.000                 5.835
# North Macedonia                         0.000                 0.000
# Gambia                                  0.000                 0.000
#
#                          Happiness Score 2019
# Country or Region
# Switzerland                             7.480
# Iceland                                 7.494
# Denmark                                 7.600
# Norway                                  7.554
# Canada                                  7.278
# ...                                       ...
# Hong Kong S.A.R., China                 0.000
# Trinidad & Tobago                       6.192
# Northern Cyprus                         5.718
# North Macedonia                         5.274
# Gambia                                  4.516
#
# [170 rows x 5 columns]

# %%
transposed_rank = combined_df_all[["Happiness Rank 2015", "Happiness Rank 2016", "Happiness Rank 2017", "Happiness Rank 2018", "Happiness Rank 2019"]]
transposed_rank
# Out:
#                          Happiness Rank 2015  Happiness Rank 2016  \
# Country or Region
# Switzerland                              1.0                  2.0
# Iceland                                  2.0                  3.0
# Denmark                                  3.0                  1.0
# Norway                                   4.0                  4.0
# Canada                                   5.0                  6.0
# ...                                      ...                  ...
# Hong Kong S.A.R., China                  0.0                  0.0
# Trinidad & Tobago                        0.0                  0.0
# Northern Cyprus                          0.0                  0.0
# North Macedonia                          0.0                  0.0
# Gambia                                   0.0                  0.0
#
#                          Happiness Rank 2017  Happiness Rank 2018  \
# Country or Region
# Switzerland                              4.0                  5.0
# Iceland                                  3.0                  4.0
# Denmark                                  2.0                  3.0
# Norway                                   1.0                  2.0
# Canada                                   7.0                  7.0
# ...                                      ...                  ...
# Hong Kong S.A.R., China                 71.0                  0.0
# Trinidad & Tobago                        0.0                 38.0
# Northern Cyprus                          0.0                 58.0
# North Macedonia                          0.0                  0.0
# Gambia                                   0.0                  0.0
#
#                          Happiness Rank 2019
# Country or Region
# Switzerland                              6.0
# Iceland                                  4.0
# Denmark                                  2.0
# Norway                                   3.0
# Canada                                   9.0
# ...                                      ...
# Hong Kong S.A.R., China                  0.0
# Trinidad & Tobago                       39.0
# Northern Cyprus                         64.0
# North Macedonia                         84.0
# Gambia                                 120.0
#
# [170 rows x 5 columns]

# %%
new_df.mean()
# Out:
# Happiness Score 2015    4.996271
# Happiness Score 2016    4.970606
# Happiness Score 2017    4.881606
# Happiness Score 2018    4.933194
# Happiness Score 2019    4.961806
# dtype: float64

# %%
new_df.describe()
# Out:
#        Happiness Score 2015  Happiness Score 2016  Happiness Score 2017  \
# count            170.000000            170.000000            170.000000
# mean               4.996271              4.970606              4.881606
# std                1.767789              1.805840              1.867052
# min                0.000000              0.000000              0.000000
# 25%                4.336500              4.223250              4.182500
# 50%                5.126500              5.181000              5.232000
# 75%                6.093000              6.147000              6.055250
# max                7.587000              7.526000              7.537000
#
#        Happiness Score 2018  Happiness Score 2019
# count            170.000000            170.000000
# mean               4.933194              4.961806
# std                1.829325              1.832733
# min                0.000000              0.000000
# 25%                4.342500              4.397000
# 50%                5.250000              5.263000
# 75%                6.102750              6.123250
# max                7.632000              7.769000

# %%
new_df.head(20)
# Out:
#                       Happiness Score 2015  Happiness Score 2016  \
# Country or Region
# Switzerland                          7.587                 7.509
# Iceland                              7.561                 7.501
# Denmark                              7.527                 7.526
# Norway                               7.522                 7.498
# Canada                               7.427                 7.404
# Finland                              7.406                 7.413
# Netherlands                          7.378                 7.339
# Sweden                               7.364                 7.291
# New Zealand                          7.286                 7.334
# Australia                            7.284                 7.313
# Israel                               7.278                 7.267
# Costa Rica                           7.226                 7.087
# Austria                              7.200                 7.119
# Mexico                               7.187                 6.778
# United States                        7.119                 7.104
# Brazil                               6.983                 6.952
# Luxembourg                           6.946                 6.871
# Ireland                              6.940                 6.907
# Belgium                              6.937                 6.929
# United Arab Emirates                 6.901                 6.573
#
#                       Happiness Score 2017  Happiness Score 2018  \
# Country or Region
# Switzerland                          7.494                 7.487
# Iceland                              7.504                 7.495
# Denmark                              7.522                 7.555
# Norway                               7.537                 7.594
# Canada                               7.316                 7.328
# Finland                              7.469                 7.632
# Netherlands                          7.377                 7.441
# Sweden                               7.284                 7.314
# New Zealand                          7.314                 7.324
# Australia                            7.284                 7.272
# Israel                               7.213                 6.814
# Costa Rica                           7.079                 7.072
# Austria                              7.006                 7.139
# Mexico                               6.578                 6.488
# United States                        6.993                 6.886
# Brazil                               6.635                 6.419
# Luxembourg                           6.863                 6.910
# Ireland                              6.977                 6.977
# Belgium                              6.891                 6.927
# United Arab Emirates                 6.648                 6.774
#
#                       Happiness Score 2019
# Country or Region
# Switzerland                          7.480
# Iceland                              7.494
# Denmark                              7.600
# Norway                               7.554
# Canada                               7.278
# Finland                              7.769
# Netherlands                          7.488
# Sweden                               7.343
# New Zealand                          7.307
# Australia                            7.228
# Israel                               7.139
# Costa Rica                           7.167
# Austria                              7.246
# Mexico                               6.595
# United States                        6.892
# Brazil                               6.300
# Luxembourg                           7.090
# Ireland                              7.021
# Belgium                              6.923
# United Arab Emirates                 6.825

# %%
new_df.to_html()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Happiness Score 2015</th>\n      <th>Happiness Score 2016</th>\n      <th>Happiness Score 2017</th>\n      <th>Happiness Score 2018</th>\n      <th>Happiness Score 2019</th>\n    </tr>\n    <tr>\n      <th>Country or Region</th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>Switzerland</th>\n      <td>7.587</td>\n      <td>7.509</td>\n      <td>7.494</td>\n      <td>7.487</td>\n      <td>7.480</td>\n    </tr>\n    <tr>\n      <th>Iceland</th>\n      <td>7.561</td>\n      <td>7.501</td>\n      <td>7.504</td>\n      <td>7.495</td>\n      <td>7.494</td>\n    </tr>\n    <tr>\n      <th>Denmark</th>\n      <td>7.527</td>\n      <td>7.526</td>\n      <td>7.522</td>\n      <td>7.555</td>\n      <td>7.600</td>\n    </tr>\n    <tr>\n      <th>Norway</th>\n      <td>7.522</td>\n      <td>7.498</td>\n      <td>7.537</td>\n      <td>7.594</td>\n      <td>7.554</td>\n    </tr>\n    <tr>\n      <th>Canada</th>\n      <td>7.427</td>\n      <td>7.404</td>\n      <td>7.316</td>\n      <td>7.328</td>\n      <td>7.278</td>\n    </tr>\n    <tr>\n      <th>Finland</th>\n      <td>7.406</td>\n      <td>7.413</td>\n      <td>7.469</td>\n      <td>7.632</td>\n      <td>7.769</td>\n    </tr>\n    <tr>\n      <th>Netherlands</th>\n      <td>7.378</td>\n      <td>7.339</td>\n      <td>7.377</td>\n      <td>7.441</td>\n      <td>7.488</td>\n    </tr>\n    <tr>\n      <th>Sweden</th>\n      <td>7.364</td>\n      <td>7.291</td>\n      <td>7.284</td>\n      <td>7.314</td>\n      <td>7.343</td>\n    </tr>\n    <tr>\n      <th>New Zealand</th>\n      <td>7.286</td>\n      <td>7.334</td>\n      <td>7.314</td>\n      <td>7.324</td>\n      <td>7.307</td>\n    </tr>\n    <tr>\n      <th>Australia</th>\n      <td>7.284</td>\n      <td>7.313</td>\n      <td>7.284</td>\n      <td>7.272</td>\n      <td>7.228</td>\n    </tr>\n    <tr>\n      <th>Israel</th>\n      <td>7.278</td>\n      <td>7.267</td>\n      <td>7.213</td>\n      <td>6.814</td>\n      <td>7.139</td>\n    </tr>\n    <tr>\n      <th>Costa Rica</th>\n      <td>7.226</td>\n      <td>7.087</td>\n      <td>7.079</td>\n      <td>7.072</td>\n      <td>7.167</td>\n    </tr>\n    <tr>\n      <th>Austria</th>\n      <td>7.200</td>\n      <td>7.119</td>\n      <td>7.006</td>\n      <td>7.139</td>\n      <td>7.246</td>\n    </tr>\n    <tr>\n      <th>Mexico</th>\n      <td>7.187</td>\n      <td>6.778</td>\n      <td>6.578</td>\n      <td>6.488</td>\n      <td>6.595</td>\n    </tr>\n    <tr>\n      <th>United States</th>\n      <td>7.119</td>\n      <td>7.104</td>\n      <td>6.993</td>\n      <td>6.886</td>\n      <td>6.892</td>\n    </tr>\n    <tr>\n      <th>Brazil</th>\n      <td>6.983</td>\n      <td>6.952</td>\n      <td>6.635</td>\n      <td>6.419</td>\n      <td>6.300</td>\n    </tr>\n    <tr>\n      <th>Luxembourg</th>\n      <td>6.946</td>\n      <td>6.871</td>\n      <td>6.863</td>\n      <td>6.910</td>\n      <td>7.090</td>\n    </tr>\n    <tr>\n      <th>Ireland</th>\n      <td>6.940</td>\n      <td>6.907</td>\n      <td>6.977</td>\n      <td>6.977</td>\n      <td>7.021</td>\n    </tr>\n    <tr>\n      <th>Belgium</th>\n      <td>6.937</td>\n      <td>6.929</td>\n      <td>6.891</td>\n      <td>6.927</td>\n      <td>6.923</td>\n    </tr>\n    <tr>\n      <th>United Arab Emirates</th>\n      <td>6.901</td>\n      <td>6.573</td>\n      <td>6.648</td>\n      <td>6.774</td>\n      <td>6.825</td>\n    </tr>\n    <tr>\n      <th>United Kingdom</th>\n      <td>6.867</td>\n      <td>6.725</td>\n      <td>6.714</td>\n      <td>7.190</td>\n      <td>7.054</td>\n    </tr>\n    <tr>\n      <th>Oman</th>\n      <td>6.853</td>\n      <td>0.000</td>\n      <td>0.000</td>\n      <td>0.000</td>\n      <td>0.000</td>\n    </tr>\n    <tr>\n      <th>Venezuela</th>\n      <td>6.810</td>\n      <td>6.084</td>\n      <td> ...
